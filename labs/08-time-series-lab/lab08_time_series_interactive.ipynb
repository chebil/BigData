# %% [markdown]
# # Lab 8: Time Series Analysis & Forecasting
# ## Interactive Notebook
#
# ### Learning Objectives
# 1. Decompose time series
# 2. Test for stationarity
# 3. Build ARIMA models
# 4. Implement seasonal models
# 5. Forecast future values
#
# **Time:** 4-5 hours

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import warnings
warnings.filterwarnings('ignore')
print('✅ Ready!')

# %% [markdown]
# ## Part 1: Load Airline Passengers Data

# %%
# Load data
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv'
df = pd.read_csv(url)
df.columns = ['Month', 'Passengers']
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)

print(df.head())
df.plot(figsize=(12, 6), title='Airline Passengers')
plt.show()

# %% [markdown]
# ### 📝 Task: Decompose Time Series

# %%
# TODO: Perform seasonal decomposition
decomposition = # YOUR CODE HERE

# Plot components
fig, axes = plt.subplots(4, 1, figsize=(12, 10))
# YOUR CODE: Plot observed, trend, seasonal, residual

# %% [markdown]
# ## Part 2: Stationarity Test

# %%
# TODO: ADF test
result = adfuller(df['Passengers'])
print(f'ADF Statistic: {result[0]:.6f}')
print(f'p-value: {result[1]:.6f}')

if result[1] <= 0.05:
    print('✅ Stationary')
else:
    print('❌ Non-stationary - needs differencing')

# %% [markdown]
# ## Part 3: ARIMA Model

# %%
# TODO: Split data
train_size = int(len(df) * 0.8)
train = df[:train_size]
test = df[train_size:]

# TODO: Fit ARIMA(5,1,0)
model = # YOUR CODE HERE
# YOUR CODE: Fit and forecast

# %% [markdown]
# ## Part 4: SARIMA (Seasonal)

# %%
# TODO: Fit SARIMA model
sarima = SARIMAX(train, order=(1,1,1), seasonal_order=(1,1,1,12))
# YOUR CODE: Fit and forecast

# %% [markdown]
# ---
# # 📝 Summary
# ✅ Decomposed series
# ✅ Tested stationarity
# ✅ Built ARIMA model
# ✅ Applied SARIMA
# **Great forecasting! 📈**
